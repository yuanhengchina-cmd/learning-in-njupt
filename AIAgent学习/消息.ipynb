# %%
from langchain.agents import create_agent
from langchain.tools import tool
from langchain.messages import SystemMessage,AIMessage,HumanMessage
#define tool
def get_weather(location:str)->str:
    """
    Get the weather in a given location.
    Args:
     location:city_name or coordinates
    """
    return f"current weather is {location} is sunny"

#创建Agent,同时把工具传给Agent
#带有工具的智能体
agent=create_agent(model="deepseek-chat",tools=[get_weather])

#调用Agent，发送消息
response= agent.invoke(
    {"messages":[
        # {"role":"system","content":"你是一名大学生"},
        # {"role":"user","content":"你来自哪个学校"},
        # {"role":"assistant","content":"尊敬的评委，您好，我是来自南京邮电大学的考生"},
        # {"role":"user","content":"南京的天气怎么样"},
        SystemMessage(content="请使用工具来获取天气信息"),
        HumanMessage("我是用户"),
        AIMessage("我是查询系统"),
        HumanMessage("南京天气怎么样"),


    ]
    }
)
print(response)
# Out:
# {'messages': [SystemMessage(content='请使用工具来获取天气信息', additional_kwargs={}, response_metadata={}, id='4a407e5c-e897-4fd8-a08b-d38d120a8309'), HumanMessage(content='我是用户', additional_kwargs={}, response_metadata={}, id='dc885ac0-c340-4aab-9aa2-d584f4f373e6'), AIMessage(content='我是查询系统', additional_kwargs={}, response_metadata={}, id='4333c8cb-a3b0-455f-b6e6-c6d8801ffc24', tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='南京天气怎么样', additional_kwargs={}, response_metadata={}, id='74b85296-a332-458a-bde3-e5ea36be0da1'), AIMessage(content='我来帮您查询南京的天气情况。', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 52, 'prompt_tokens': 328, 'total_tokens': 380, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 328}, 'model_provider': 'deepseek', 'model_name': 'deepseek-chat', 'system_fingerprint': 'fp_eaab8d114b_prod0820_fp8_kvcache_new_kvcache_20260410', 'id': 'e1a96f88-bb39-4146-9b78-70f9e68fe7a0', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019d86e0-5d6b-7122-83fa-bf48f4f9ce3c-0', tool_calls=[{'name': 'get_weather', 'args': {'location': '南京'}, 'id': 'call_00_qSN7TV0igOWF9J6CwkcYaCH1', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 328, 'output_tokens': 52, 'total_tokens': 380, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}}), ToolMessage(content='current weather is 南京 is sunny', name='get_weather', id='08027183-c5e3-4282-a122-e8c4565b5ec9', tool_call_id='call_00_qSN7TV0igOWF9J6CwkcYaCH1'), AIMessage(content='根据查询结果，南京当前的天气是晴天。', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 10, 'prompt_tokens': 404, 'total_tokens': 414, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 320}, 'prompt_cache_hit_tokens': 320, 'prompt_cache_miss_tokens': 84}, 'model_provider': 'deepseek', 'model_name': 'deepseek-chat', 'system_fingerprint': 'fp_eaab8d114b_prod0820_fp8_kvcache_new_kvcache_20260410', 'id': 'd027c49d-f70c-4075-b8cf-dbe44ba25c1c', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d86e0-68e3-7ba3-9303-330b4af9b572-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 404, 'output_tokens': 10, 'total_tokens': 414, 'input_token_details': {'cache_read': 320}, 'output_token_details': {}})]}

# %%
for message in response['messages']:
    message.pretty_print()
# Out:
# ================================ System Message ================================
#
# 请使用工具来获取天气信息
# ================================ Human Message =================================
#
# 我是用户
# ================================== Ai Message ==================================
#
# 我是查询系统
# ================================ Human Message =================================
#
# 南京天气怎么样
# ================================== Ai Message ==================================
#
# 我来帮您查询南京的天气情况。
# Tool Calls:
#   get_weather (call_00_qSN7TV0igOWF9J6CwkcYaCH1)
#  Call ID: call_00_qSN7TV0igOWF9J6CwkcYaCH1
#   Args:
#     location: 南京
# ================================= Tool Message =================================
# Name: get_weather
#
# current weather is 南京 is sunny
# ================================== Ai Message ==================================
#
# 根据查询结果，南京当前的天气是晴天。
